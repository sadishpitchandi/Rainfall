# %%
import os
# Out:
# Running cells with 'Python 3.7.0' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\sadish\rainfall\venv ipykernel --update-deps --force-reinstall'

# %%
import os
# Out:
# Running cells with 'Python 3.7.0 (conda)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\sadish\project\machine learning\Rainfall\venv ipykernel --update-deps --force-reinstall'

# %%
# !pip install ipykernel
# Out:
# Running cells with 'Python 3.7.0 (conda)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\sadish\project\machine learning\Rainfall\venv ipykernel --update-deps --force-reinstall'

# %%
  data=pd.read_csv("C:\sadish\project\machine learning\Rainfall\work\CHENNAI\CH_NUNGAMBAKKAM.csv")
    print(data)
    data=data
    html = data.to_html()
    print(html)
# Out:
# Running cells with 'Python 3.7.0 (conda)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\sadish\project\machine learning\Rainfall\venv ipykernel --update-deps --force-reinstall'
